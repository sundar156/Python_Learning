# %% [markdown]
# ### Import matplotlib and numpy

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure()

# %% [markdown]
# ###  1.Plot a line from 0 to 10

# %%
#code goes here

# %%
plt.figure(figsize=(5,5))
plt.plot([1,2,3,4])
# ?plt.plot()
#fig=plt.figure()

# %% [markdown]
# ###  2.Plot time on x-axis and co2 and temparature in same figure

# %%
times = range(7)
co2 = [250, 265, 272, 260, 300, 320, 389]
temp = [14.1, 15.5, 16.3, 18.1, 17.3, 19.1, 20.2]
plt.plot(times, co2, 'b--', times, temp, 'r*--')

#code goes here

# %% [markdown]
# ###  3. Plot co2 in left y-axis and temp in right y-axis and time in x-axis

# %%
times = range(7)
co2 = [250, 265, 272, 260, 300, 320, 389]
temp = [14.1, 15.5, 16.3, 18.1, 17.3, 19.1, 20.2]
#code goes here
fig , x1 = plt.subplots()
x1.plot(times, co2, 'b--')
x1.set_ylabel("[CO2]")
x1.set_xlabel("time")
ax2 = x1.twinx()
ax2.plot(times,temp,'r*-')
ax2.set_ylabel("Temp (degC)")
plt.show()
#plt.plot(times, co2, 'b--')
#plt.plot(times, temp,'r*-')

# %% [markdown]
# ###  4. Create sine wave

# %%
#code goes here

# %%
import numpy as np
t = np.arange(0.0, 2.0, 0.01)
x=np.sin(2*np.pi*t)
plt.plot(t, x)
plt.xlabel("time (s)")
plt.ylabel("ç")
plt.grid(True)
plt.savefig("test.png")
plt.show()

# %% [markdown]
# ###  5. Insert a figure inside another figure

# %%
X = [1, 2, 3, 4, 5, 6, 7]
Y = [1, 3, 4, 2, 5, 8, 6]
#code goes here
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.9,0.9])
axes2 = fig.add_axes([0.2,0.6,0.4,0.3])
axes1.plot(X,Y,'r')
axes1.set_title("title")
axes1.set_xlabel("x")
axes1.set_ylabel("y")
axes2.plot(Y,X,'g')
axes2.set_title("inner title")
axes2.set_xlabel("y")
axes2.set_ylabel("x")
plt.show()

# %% [markdown]
# ### 6. Plot both side of X-axis
# Plot Y1 and Y2 on X-axis

# %%
n = 12
X = np.arange(n)
Y1 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
Y2 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
#code goes here


#plt.axes([0.025,0.025,0.95,0.95])
plt.axes([0.025,0.025,0.95,0.95])
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X, -Y2,facecolor='#ff9999',edgecolor='white')

for x,y in zip(X,Y1):
    plt.text(x+0.4, y+0.05, '%.2f' % y, ha='center', va= 'bottom')
    
for x,y in zip(X,Y2):
    plt.text(x+0.4, -y-0.05, '%.2f' % y, ha='center', va= 'top')

plt.xlim(-.5,n),plt.xticks([])
plt.ylim(-1.25,+1.25),plt.yticks([])
plt.show()

# %% [markdown]
# ### 7. Pie-Chart

# %%
labels = 'Option one', 'Option 2', 'Option 3', 'Option 4' , 'Option 5'
sizes = [25, 5, 50, 10, 10]
colors = ['lightseagreen', 'lightsalmon', 'lightskyblue', 'lightcoral', 'lightgreen']
#code goes here
explode = (0, 0.2, 0, 0.1, 0)
fig, x1 = plt.subplots()
x1.pie(sizes,labels=labels,colors=colors,startangle=90,explode=explode, 
       counterclock=False, textprops={"fontweight":"bold", "fontsize":"large"})
#x1.plot()
plt.axis('equal')

plt.show()
